# %%
from dotenv import load_dotenv
import os
from langchain.document_loaders import PyPDFLoader
from langchain_core.documents import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_anthropic import ChatAnthropic
from langchain_experimental.graph_transformers import LLMGraphTransformer
from langchain.graphs import Neo4jGraph
from langchain_neo4j import GraphCypherQAChain, Neo4jGraph
import sys
import os
sys.path.insert(0, os.path.abspath('..'))
from utils.visualizer import visualize_neo4j_graph

load_dotenv()
# Get API key from environment variable 
api_key = os.getenv("ANTHROPIC_API_KEY")

if not api_key:
    print("Warning: ANTHROPIC_API_KEY not found in environment variables")
    print("Please add ANTHROPIC_API_KEY=your_api_key_here to your .env file")
else:
    print("Anthropic API key loaded successfully")

# Use Claude 3.5 Sonnet with increased max_tokens
llm = ChatAnthropic(
    model="claude-3-5-sonnet-20241022",
    temperature=0.1,  # Very low temperature for consistent extraction
    max_tokens=8192,  # Increased max_tokens to avoid truncation
    anthropic_api_key=api_key
)

# Create graph transformer with the fixed LLM
graph_transformer = LLMGraphTransformer(
    llm=llm,
    node_properties=False,  # Disabled to reduce token usage
    relationship_properties=False  # Disabled to reduce token usage
)

print(f"✓ Claude LLM initialized with max_tokens=8192")
print(f"✓ Graph transformer created")
# Out:
# Anthropic API key loaded successfully
# ✓ Claude LLM initialized with max_tokens=8192
# ✓ Graph transformer created

# %%
import pandas as pd
from langchain_core.documents import Document

csv_file = r"/Users/kathisnehith/Downloads/healthcare_dataset.csv"
df = pd.read_csv(csv_file)

# ✅ Limit to first 1500 rows
df = df.head(100)

lc_docs = []

for idx, row in df.iterrows():
    # Convert each row to a readable string
    row_str = ", ".join([f"{col}: {val}" for col, val in row.items()])

    # Create LangChain Document with metadata
    lc_docs.append(Document(
        page_content=row_str,
        metadata={'row': idx, 'source': csv_file}
    ))

    # Optional: Print preview
    print(f"Row {idx} processed: {row_str[:10]}...")
print(f"✓ {len(lc_docs)} documents created from CSV rows")
# Out:
# Row 0 processed: Name: Tiff...
# Row 1 processed: Name: Rube...
# Row 2 processed: Name: Chad...
# Row 3 processed: Name: Anto...
# Row 4 processed: Name: Mrs....
# Row 5 processed: Name: Patr...
# Row 6 processed: Name: Char...
# Row 7 processed: Name: Patt...
# Row 8 processed: Name: Ryan...
# Row 9 processed: Name: Shar...
# Row 10 processed: Name: Amy ...
# Row 11 processed: Name: Mrs....
# Row 12 processed: Name: Chri...
# Row 13 processed: Name: Will...
# Row 14 processed: Name: Mich...
# Row 15 processed: Name: Bria...
# Row 16 processed: Name: Oliv...
# Row 17 processed: Name: Tere...
# Row 18 processed: Name: Desi...
# Row 19 processed: Name: Sall...
# Row 20 processed: Name: Will...
# Row 21 processed: Name: Stev...
# Row 22 processed: Name: Hale...
# Row 23 processed: Name: Ange...
# Row 24 processed: Name: Beve...
# Row 25 processed: Name: Dani...
# Row 26 processed: Name: Kimb...
# Row 27 processed: Name: Fran...
# Row 28 processed: Name: Ronn...
# Row 29 processed: Name: Shan...
# Row 30 processed: Name: Tere...
# Row 31 processed: Name: Rodn...
# Row 32 processed: Name: Kevi...
# Row 33 processed: Name: Rebe...
# Row 34 processed: Name: Lind...
# Row 35 processed: Name: Jenn...
# Row 36 processed: Name: Anna...
# Row 37 processed: Name: Mari...
# Row 38 processed: Name: Bren...
# Row 39 processed: Name: Mich...
# Row 40 processed: Name: Migu...
# Row 41 processed: Name: Mr. ...
# Row 42 processed: Name: Ther...
# Row 43 processed: Name: Laur...
# Row 44 processed: Name: Laur...
# Row 45 processed: Name: Chri...
# Row 46 processed: Name: Kyle...
# Row 47 processed: Name: Jasm...
# Row 48 processed: Name: John...
# Row 49 processed: Name: Just...
# Row 50 processed: Name: Dyla...
# Row 51 processed: Name: Oliv...
# Row 52 processed: Name: Fran...
# Row 53 processed: Name: Rach...
# Row 54 processed: Name: Lori...
# Row 55 processed: Name: Fran...
# Row 56 processed: Name: Cynt...
# Row 57 processed: Name: Nico...
# Row 58 processed: Name: Mich...
# Row 59 processed: Name: Kenn...
# Row 60 processed: Name: Gabr...
# Row 61 processed: Name: Mary...
# Row 62 processed: Name: Evan...
# Row 63 processed: Name: Aman...
# Row 64 processed: Name: Paul...
# Row 65 processed: Name: Lisa...
# Row 66 processed: Name: Ange...
# Row 67 processed: Name: Kimb...
# Row 68 processed: Name: Fran...
# Row 69 processed: Name: Kenn...
# Row 70 processed: Name: Chri...
# Row 71 processed: Name: Ryan...
# Row 72 processed: Name: Lind...
# Row 73 processed: Name: Anna...
# Row 74 processed: Name: Juan...
# Row 75 processed: Name: Migu...
# Row 76 processed: Name: Tyle...
# Row 77 processed: Name: Lisa...
# Row 78 processed: Name: Davi...
# Row 79 processed: Name: Tere...
# Row 80 processed: Name: Jona...
# Row 81 processed: Name: Doug...
# Row 82 processed: Name: Anth...
# Row 83 processed: Name: Kimb...
# Row 84 processed: Name: Trav...
# Row 85 processed: Name: Aman...
# Row 86 processed: Name: Keit...
# Row 87 processed: Name: Jess...
# Row 88 processed: Name: Mich...
# Row 89 processed: Name: Jess...
# Row 90 processed: Name: Thom...
# Row 91 processed: Name: Arie...
# Row 92 processed: Name: Joyc...
# Row 93 processed: Name: Jerm...
# Row 94 processed: Name: Jaso...
# Row 95 processed: Name: Samu...
# Row 96 processed: Name: Stev...
# Row 97 processed: Name: Gabr...
# Row 98 processed: Name: Chri...
# Row 99 processed: Name: Chri...
# ✓ 100 documents created from CSV rows

# %%
# Convert to graph documents
graph_documents_lc = graph_transformer.convert_to_graph_documents(lc_docs)
print(lc_docs)
# Out:
# [Document(metadata={'row': 0, 'source': '/Users/kathisnehith/Downloads/healthcare_dataset.csv'}, page_content='Name: Tiffany Ramirez, Age: 81, Gender: Female, Blood Type: O-, Medical Condition: Diabetes, Date of Admission: 2022-11-17, Doctor: Patrick Parker, Hospital: Wallace-Hamilton, Insurance Provider: Medicare, Billing Amount: 37490.98336352819, Room Number: 146, Admission Type: Elective, Discharge Date: 2022-12-01, Medication: Aspirin, Test Results: Inconclusive'), Document(metadata={'row': 1, 'source': '/Users/kathisnehith/Downloads/healthcare_dataset.csv'}, page_content='Name: Ruben Burns, Age: 35, Gender: Male, Blood Type: O+, Medical Condition: Asthma, Date of Admission: 2023-06-01, Doctor: Diane Jackson, Hospital: Burke, Griffin and Cooper, Insurance Provider: UnitedHealthcare, Billing Amount: 47304.06484547511, Room Number: 404, Admission Type: Emergency, Discharge Date: 2023-06-15, Medication: Lipitor, Test Results: Normal'), Document(metadata={'row': 2, 'source': '/Users/kathisnehith/Downloads/healthcare_dataset.csv'}, page_content='Name: Chad Byrd, Age: 61, Gender: Male, Blood Type: B-, Medical Condition: Obesity, Date of Admission: 2019-01-09, Doctor: Paul Baker, Hospital: Walton LLC, Insurance Provider: Medicare, Billing Amount: 36874.89699661277, Room Number: 292, Admission Type: Emergency, Discharge Date: 2019-02-08, Medication: Lipitor, Test Results: Normal'), Document(metadata={'row': 3, 'source': '/Users/kathisnehith/Downloads/healthcare_dataset.csv'}, page_content='Name: Antonio Frederick, Age: 49, Gender: Male, Blood Type: B-, Medical Condition: Asthma, Date of Admission: 2020-05-02, Doctor: Brian Chandler, Hospital: Garcia Ltd, Insurance Provider: Medicare, Billing Amount: 23303.322092196904, Room Number: 480, Admission Type: Urgent, Discharge Date: 2020-05-03, Medication: Penicillin, Test Results: Abnormal'), Document(metadata={'row': 4, 'source': '/Users/kathisnehith/Downloads/healthcare_dataset.csv'}, page_content='Name: Mrs. Brandy Flowers, Age: 51, Gender: Male, Blood Type: O-, Medical Condition: Arthritis, Date of Admission: 2021-07-09, Doctor: Dustin Griffin, Hospital: Jones, Brown and Murray, Insurance Provider: UnitedHealthcare, Billing Amount: 18086.344183563877, Room Number: 477, Admission Type: Urgent, Discharge Date: 2021-08-02, Medication: Paracetamol, Test Results: Normal'), Document(metadata={'row': 5, 'source': '/Users/kathisnehith/Downloads/healthcare_dataset.csv'}, page_content='Name: Patrick Parker, Age: 41, Gender: Male, Blood Type: AB+, Medical Condition: Arthritis, Date of Admission: 2020-08-20, Doctor: Robin Green, Hospital: Boyd PLC, Insurance Provider: Aetna, Billing Amount: 22522.363384853263, Room Number: 180, Admission Type: Urgent, Discharge Date: 2020-08-23, Medication: Aspirin, Test Results: Abnormal'), Document(metadata={'row': 6, 'source': '/Users/kathisnehith/Downloads/healthcare_dataset.csv'}, page_content='Name: Charles Horton, Age: 82, Gender: Male, Blood Type: AB+, Medical Condition: Hypertension, Date of Admission: 2021-03-22, Doctor: Patricia Bishop, Hospital: Wheeler, Bryant and Johns, Insurance Provider: Cigna, Billing Amount: 39593.4357611308, Room Number: 161, Admission Type: Urgent, Discharge Date: 2021-04-15, Medication: Lipitor, Test Results: Abnormal'), Document(metadata={'row': 7, 'source': '/Users/kathisnehith/Downloads/healthcare_dataset.csv'}, page_content='Name: Patty Norman, Age: 55, Gender: Female, Blood Type: O-, Medical Condition: Arthritis, Date of Admission: 2019-05-16, Doctor: Brian Kennedy, Hospital: Brown Inc, Insurance Provider: Blue Cross, Billing Amount: 13546.817249364824, Room Number: 384, Admission Type: Elective, Discharge Date: 2019-06-02, Medication: Aspirin, Test Results: Normal'), Document(metadata={'row': 8, 'source': '/Users/kathisnehith/Downloads/healthcare_dataset.csv'}, page_content='Name: Ryan Hayes, Age: 33, Gender: Male, Blood Type: A+, Medical Condition: Diabetes, Date of Admission: 2020-12-17, Doctor: Kristin Dunn, Hospi ...
# Nodes:[Node(id='Ruben Burns', type='Person', properties={}), Node(id='Diane Jackson', type='Person', properties={}), Node(id='Burke, Griffin And Cooper', type='Hospital', properties={}), Node(id='Unitedhealthcare', type='Organization', properties={}), Node(id='Lipitor', type='Medicine', properties={}), Node(id='Asthma', type='Condition', properties={}), Node(id='Room 404', type='Location', properties={})]
# Relationships:[Relationship(source=Node(id='Ruben Burns', type='Person', properties={}), target=Node(id='Asthma', type='Condition', properties={}), type='HAS_CONDITION', properties={}), Relationship(source=Node(id='Diane Jackson', type='Person', properties={}), target=Node(id='Ruben Burns', type='Person', properties={}), type='TREATS', properties={}), Relationship(source=Node(id='Ruben Burns', type='Person', properties={}), target=Node(id='Burke, Griffin And Cooper', type='Hospital', properties={}), type='ADMITTED_TO', properties={}), Relationship(source=Node(id='Unitedhealthcare', type='Organization', properties={}), target=Node(id='Ruben Burns', type='Person', properties={}), type='INSURES', properties={}), Relationship(source=Node(id='Ruben Burns', type='Person', properties={}), target=Node(id='Lipitor', type='Medicine', properties={}), type='TAKES', properties={}), Relationship(source=Node(id='Ruben Burns', type='Person', properties={}), target=Node(id='Room 404', type='Location', properties={}), type='ASSIGNED_TO', properties={})]

# %%
# nodes and relationships extracted from the second document chunk
print(f"Nodes:{graph_documents_lc[0].nodes}")
print(f"Relationships:{graph_documents_lc[2].relationships}")
# Out:
# Nodes:[Node(id='Tiffany Ramirez', type='Person', properties={}), Node(id='Patrick Parker', type='Person', properties={}), Node(id='Wallace-Hamilton', type='Hospital', properties={}), Node(id='Medicare', type='Organization', properties={}), Node(id='Diabetes', type='Disease', properties={}), Node(id='Aspirin', type='Medicine', properties={}), Node(id='Room 146', type='Location', properties={})]
# Relationships:[Relationship(source=Node(id='Chad Byrd', type='Person', properties={}), target=Node(id='Obesity', type='Condition', properties={}), type='HAS_CONDITION', properties={}), Relationship(source=Node(id='Paul Baker', type='Person', properties={}), target=Node(id='Chad Byrd', type='Person', properties={}), type='TREATS', properties={}), Relationship(source=Node(id='Chad Byrd', type='Person', properties={}), target=Node(id='Walton Llc', type='Hospital', properties={}), type='ADMITTED_TO', properties={}), Relationship(source=Node(id='Chad Byrd', type='Person', properties={}), target=Node(id='Medicare', type='Organization', properties={}), type='HAS_INSURANCE', properties={}), Relationship(source=Node(id='Chad Byrd', type='Person', properties={}), target=Node(id='Lipitor', type='Medicine', properties={}), type='TAKES', properties={}), Relationship(source=Node(id='Chad Byrd', type='Person', properties={}), target=Node(id='Room 292', type='Location', properties={}), type='ASSIGNED_TO', properties={})]

# %%
from pyvis.network import Network

def visualize_graph(graph_documents):

    # Create network
    net = Network(height="1200px", width="100%", directed=True,
                      notebook=False, bgcolor="#222222", font_color="white")
    
    nodes = graph_documents[0].nodes
    relationships = graph_documents[0].relationships

    # Build lookup for valid nodes
    node_dict = {node.id: node for node in nodes}
    
    # Filter out invalid edges and collect valid node IDs
    valid_edges = []
    valid_node_ids = set()
    for rel in relationships:
        if rel.source.id in node_dict and rel.target.id in node_dict:
            valid_edges.append(rel)
            valid_node_ids.update([rel.source.id, rel.target.id])


    # Track which nodes are part of any relationship
    connected_node_ids = set()
    for rel in relationships:
        connected_node_ids.add(rel.source.id)
        connected_node_ids.add(rel.target.id)

    # Add valid nodes
    for node_id in valid_node_ids:
        node = node_dict[node_id]
        try:
            net.add_node(node.id, label=node.id, title=node.type, group=node.type)
        except:
            continue  # skip if error

    # Add valid edges
    for rel in valid_edges:
        try:
            net.add_edge(rel.source.id, rel.target.id, label=rel.type.lower())
        except:
            continue  # skip if error

    # Configure physics
    net.set_options("""
            {
                "physics": {
                    "forceAtlas2Based": {
                        "gravitationalConstant": -100,
                        "centralGravity": 0.01,
                        "springLength": 200,
                        "springConstant": 0.08
                    },
                    "minVelocity": 0.75,
                    "solver": "forceAtlas2Based"
                }
            }
            """)
        
    output_file = "knowledge_graph.html"
    net.save_graph(output_file)
    print(f"Graph saved to {os.path.abspath(output_file)}")

    # Try to open in browser
    try:
        import webbrowser
        webbrowser.open(f"file://{os.path.abspath(output_file)}")
    except:
        print("Could not open browser automatically")
        
# Run the function
visualize_graph(graph_documents_lc)
# Out:
# Graph saved to /Users/kathisnehith/Desktop/Med-GraphRAG-project/notebooks/knowledge_graph.html

# %%
graph = Neo4jGraph(url=os.getenv("NEO4J_URI"), 
                username=os.getenv("NEO4J_USERNAME"), 
                password=os.getenv("NEO4J_PASSWORD"),
                enhanced_schema=True)

# %%
# add the graph documents to the Neo4j graph
print("Adding graph documents to Neo4j...")
graph.add_graph_documents(graph_documents_lc, include_source=True)


# Get the schema of the graph
schema = graph.get_schema
print("Sucessfully! Added and Graph schema retrieved.........")
print("Graph schema: \n", schema)
# Out:
# Adding graph documents to Neo4j...
# Sucessfully! Added and Graph schema retrieved.........
# Graph schema:
#  Node properties:
# - **Document**
#   - `id`: STRING Example: "52852b3fe189de1d135bea41e887857e"
#   - `text`: STRING Example: "Prompt  EngineeringAuthor: Lee Boonstra"
#   - `page`: INTEGER Min: 0, Max: 67
#   - `source`: STRING Available options: ['/Users/kathisnehith/Downloads/22365_3_Prompt Engin']
# - **Person**
#   - `id`: STRING Example: "Lee Boonstra"
# - **Book**
#   - `id`: STRING Available options: ['Prompt Engineering']
# - **Topic**
#   - `id`: STRING Example: "Introduction"
# - **Technique**
#   - `id`: STRING Example: "Step-Back Prompting"
# - **Concept**
#   - `id`: STRING Example: "Best Practices"
# - **Practice**
#   - `id`: STRING Available options: ['Provide Examples', 'Design With Simplicity', 'Be Specific About Output', 'Use Instructions Over Constraints', 'Control Max Token Length', 'Use Variables In Prompts', 'Experiment With Input Formats', 'Mix Up Classes In Few-Shot Prompting', 'Adapt To Model Updates', 'Experiment With Output Formats']
# - **Profession**
#   - `id`: STRING Available options: ['Data_Scientist', 'Machine_Learning_Engineer']
# - **Technology**
#   - `id`: STRING Example: "Llm"
# - **Task**
#   - `id`: STRING Example: "Text Summarization"
# - **Parameter**
#   - `id`: STRING Available options: ['Temperature', 'Top_K', 'Top_P', 'Token_Limit']
# - **Output**
#   - `id`: STRING Available options: ['Coherent_Results', 'Creative_Results', 'Less_Creative_Results']
# - **Issue**
#   - `id`: STRING Available options: ['Repetition_Loop_Bug']
# - **Software**
#   - `id`: STRING Example: "Vertex Ai Studio"
# - **Feature**
#   - `id`: STRING Available options: ['Language', 'Noise Cancellation', 'Bluetooth 5.0', '20-Hour Battery Life']
# - **Content**
#   - `id`: STRING Available options: ['Movie Reviews', 'Blog_Post']
# - **Movie**
#   - `id`: STRING Available options: ['Her']
# - **Model**
#   - `id`: STRING Available options: ['Gemini_Pro', 'Gemini-Pro']
# - **Example**
#   - `id`: STRING Available options: ['Pizza_Order_Example', 'Large_Pizza_Tomato_Sauce', 'Large_Pizza_Half_Half', 'Travel Guide Example', 'Video_Game_Consoles_Example']
# - **Process**
#   - `id`: STRING Available options: ['Text_Generation', 'Prompt Engineering', 'Automated Tests', 'Evaluation Procedures']
# - **Format**
#   - `id`: STRING Available options: ['Json_Format', 'Json', 'Markdown', 'Text', 'Images', 'Audio', 'Code', 'Xml']
# - **Schema**
#   - `id`: STRING Available options: ['Movie_Reviews', 'Product Schema']
# - **Attribute**
#   - `id`: STRING Available options: ['Sentiment', 'Name']
# - **Role**
#   - `id`: STRING Available options: ['Book_Editor', 'Kindergarten_Teacher', 'Motivational_Speaker', 'Travel_Guide', 'Travel Guide']
# - **Location**
#   - `id`: STRING Example: "Rijksmuseum"
# - **Artwork**
#   - `id`: STRING Available options: ['The Night Watch', 'The Starry Night', 'Sunflowers']
# - **Article**
#   - `id`: STRING Available options: ['Evolution_Of_Arcade_Cabinet_Design', 'Iconic_Arcade_Games_80S', 'Pixel_Art_Evolution']
# - **Blog**
#   - `id`: STRING Available options: ['Retro_Games_Blog']
# - **Game**
#   - `id`: STRING Available options: ['First_Person_Shooter_Level']
# - **Group**
#   - `id`: STRING Available options: ['Player_Squad', 'Enemy_Faction']
# - **Information**
#   - `id`: STRING Available options: ['Intel', 'Enemy_Attack_Plan']
# - **Character**
#   - `id`: STRING Available options: ['Mutated Soldiers', 'Rogue Robots', 'Cybernetically Enhanced Enemies', 'Extraterrestrial Creatures', 'Zombies', 'Mutated Aquatic Creatures']
# - **Equipment**
#   - `id`: STRING Available options: ['Advanced Diving Gear', 'Experimental Weaponry']
# - **System**
#   - `id`: STRING Available options: ['Email Classification System', 'E-Commerce Catalog', 'Rag System', 'Project Codebase']
# - **Date**
#   - `id`: STRING Available options: ['February 2025']
# - **Website**
#   - `id`: STRING Available options: ['Website']
# - **Bug**
#   - `id`: STRING Available options: ['Javascript Bug']
# - **Code**
#   - `id`: STRING Available options: ['Python_Code', 'Python_Rename_Files', 'Bash_Code']
# - **Service**
#   - `id`: STRING Available options: ['Serpapi']
# - **Organization**
#   - `id`: STRING Available options: ['Metallica', 'Google', 'Google Cloud']
# - **Business**
#   - `id`: STRING Available options: ['T-Shirt Webshop', 'Webshop']
# - **Product**
#   - `id`: STRING Available options: ['Metallica T-Shirt', 'Sega Dreamcast', 'Wireless Headphones']
# - **Variable**
#   - `id`: STRING Available options: ['Folder_Name', 'Draft', 'Prefix', 'Text', 'File', 'New_Filename']
# - **File**
#   - `id`: STRING Available options: ['Rename_Files.Sh', 'Filename.Txt', 'Draft_Filename.Txt', 'File_Renamer.Py', 'Rename_Files.Py']
# - **Folder**
#   - `id`: STRING Available options: ['Test']
# - **Text**
#   - `id`: STRING Available options: ['Code']
# - **Action**
#   - `id`: STRING Available options: ['User Input', 'Folder Check']
# - **Message**
#   - `id`: STRING Available options: ['Error Message']
# - **Object**
#   - `id`: STRING Available options: ['Files', 'Folder_Name', 'New_File_Name', 'Success_Message']
# - **Function**
#   - `id`: STRING Available options: ['Basename', 'Mv', 'For_Loop', 'Touppercase', 'Upper()', 'Os.Path.Isdir', 'Os.Listdir', 'Shutil.Move']
# - **Language**
#   - `id`: STRING Available options: ['Python', 'Bash']
# - **Error**
#   - `id`: STRING Available options: ['Nameerror']
# - **Activity**
#   - `id`: STRING Available options: ['Code Review', 'File Renaming']
# - **Tool**
#   - `id`: STRING Available options: ['Language_Studio', 'Vertex Ai Studio', 'Google Sheet']
# - **Platform**
#   - `id`: STRING Available options: ['Vertex_Ai', 'Pypi', 'Arxiv']
# - **List**
#   - `id`: STRING Available options: ['Verb List']
# - **Property**
#   - `id`: STRING Available options: ['Name', 'Category', 'Price', 'Features', 'Release_Date']
# - **Category**
#   - `id`: STRING Available options: ['Electronics']
# - **Research**
#   - `id`: STRING Available options: ['Zero Shot', 'Few Shot', 'Take A Step Back', 'Chain Of Thought Prompting', 'Self Consistency', 'Tree Of Thoughts', 'React']
# - **Publication**
#   - `id`: STRING Available options: ['Automatic Prompt Engineering - Large Language Mode']
# Relationship properties:
#
# The relationships:
# (:Document)-[:MENTIONS]->(:Person)
# (:Document)-[:MENTIONS]->(:Book)
# (:Document)-[:MENTIONS]->(:Document)
# (:Document)-[:MENTIONS]->(:Topic)
# (:Document)-[:MENTIONS]->(:Technique)
# (:Document)-[:MENTIONS]->(:Concept)
# (:Document)-[:MENTIONS]->(:Practice)
# (:Document)-[:MENTIONS]->(:Profession)
# (:Document)-[:MENTIONS]->(:Technology)
# (:Document)-[:MENTIONS]->(:Task)
# (:Document)-[:MENTIONS]->(:Parameter)
# (:Document)-[:MENTIONS]->(:Output)
# (:Document)-[:MENTIONS]->(:Issue)
# (:Document)-[:MENTIONS]->(:Software)
# (:Document)-[:MENTIONS]->(:Feature)
# (:Document)-[:MENTIONS]->(:Content)
# (:Document)-[:MENTIONS]->(:Movie)
# (:Document)-[:MENTIONS]->(:Model)
# (:Document)-[:MENTIONS]->(:Example)
# (:Document)-[:MENTIONS]->(:Process)
# (:Document)-[:MENTIONS]->(:Format)
# (:Document)-[:MENTIONS]->(:Schema)
# (:Document)-[:MENTIONS]->(:Attribute)
# (:Document)-[:MENTIONS]->(:Role)
# (:Document)-[:MENTIONS]->(:Location)
# (:Document)-[:MENTIONS]->(:Artwork)
# (:Document)-[:MENTIONS]->(:Article)
# (:Document)-[:MENTIONS]->(:Blog)
# (:Document)-[:MENTIONS]->(:Game)
# (:Document)-[:MENTIONS]->(:Group)
# (:Document)-[:MENTIONS]->(:Information)
# (:Document)-[:MENTIONS]->(:Character)
# (:Document)-[:MENTIONS]->(:Equipment)
# (:Document)-[:MENTIONS]->(:System)
# (:Document)-[:MENTIONS]->(:Date)
# (:Document)-[:MENTIONS]->(:Website)
# (:Document)-[:MENTIONS]->(:Bug)
# (:Document)-[:MENTIONS]->(:Code)
# (:Document)-[:MENTIONS]->(:Service)
# (:Document)-[:MENTIONS]->(:Organization)
# (:Document)-[:MENTIONS]->(:Business)
# (:Document)-[:MENTIONS]->(:Product)
# (:Document)-[:MENTIONS]->(:Variable)
# (:Document)-[:MENTIONS]->(:File)
# (:Document)-[:MENTIONS]->(:Folder)
# (:Document)-[:MENTIONS]->(:Action)
# (:Document)-[:MENTIONS]->(:Message)
# (:Document)-[:MENTIONS]->(:Object)
# (:Document)-[:MENTIONS]->(:Function)
# (:Document)-[:MENTIONS]->(:Language)
# (:Document)-[:MENTIONS]->(:Error)
# (:Document)-[:MENTIONS]->(:Activity)
# (:Document)-[:MENTIONS]->(:Tool)
# (:Document)-[:MENTIONS]->(:Platform)
# (:Document)-[:MENTIONS]->(:List)
# (:Document)-[:MENTIONS]->(:Property)
# (:Document)-[:MENTIONS]->(:Category)
# (:Document)-[:MENTIONS]->(:Publication)
# (:Document)-[:CONTAINS]->(:Technique)
# (:Document)-[:CONTAINS]->(:Concept)
# (:Document)-[:CONTAINS]->(:Code)
# (:Document)-[:DATED]->(:Date)
# (:Document)-[:DISCUSSES]->(:Task)
# (:Document)-[:RECOMMENDS]->(:Concept)
# (:Document)-[:AUTHORED_BY]->(:Person)
# (:Document)-[:DESCRIBES]->(:Software)
# (:Document)-[:USES]->(:Model)
# (:Person)-[:AUTHOR]->(:Book)
# (:Person)-[:CONTRIBUTOR]->(:Document)
# (:Person)-[:CURATOR]->(:Document)
# (:Person)-[:TECHNICAL_WRITER]->(:Document)
# (:Person)-[:DESIGNER]->(:Document)
# (:Person)-[:EXPLORES]->(:Location)
# (:Person)-[:USES]->(:Equipment)
# (:Person)-[:HAS_VALUE]->(:Concept)
# (:Person)-[:EXPLOITED]->(:Software)
# (:Person)-[:DISCOVERED]->(:Bug)
# (:Person)-[:READS]->(:Website)
# (:Person)-[:AUTHORED]->(:Document)
# (:Person)-[:AUTHORED]->(:Research)
# (:Person)-[:AUTHORED]->(:Publication)
# (:Person)-[:MEMBER_OF]->(:Organization)
# (:Person)-[:MARRIED_TO]->(:Person)
# (:Person)-[:PARENT_OF]->(:Person)
# (:Topic)-[:INCLUDES]->(:Concept)
# (:Topic)-[:INCLUDES]->(:Topic)
# (:Topic)-[:CONTAINS]->(:Topic)
# (:Topic)-[:PRECEDES]->(:Topic)
# (:Concept)-[:INCLUDES]->(:Practice)
# (:Concept)-[:INCLUDES]->(:Concept)
# (:Concept)-[:INCLUDES]->(:Role)
# (:Concept)-[:INCLUDES]->(:Format)
# (:Concept)-[:GUIDES]->(:Technology)
# (:Concept)-[:GUIDES]->(:Process)
# (:Concept)-[:INPUT_TO]->(:Concept)
# (:Concept)-[:REQUIRES]->(:Concept)
# (:Concept)-[:PREFERS]->(:Concept)
# (:Concept)-[:RECOMMENDS]->(:Concept)
# (:Concept)-[:USES]->(:Concept)
# (:Concept)-[:USES]->(:Technology)
# (:Concept)-[:USES]->(:Format)
# (:Concept)-[:DESIGNS]->(:Concept)
# (:Concept)-[:ENABLES]->(:Task)
# (:Concept)-[:ENABLES]->(:Concept)
# (:Concept)-[:ENABLES]->(:Technology)
# (:Concept)-[:USED_IN]->(:Technology)
# (:Concept)-[:IMPACTS]->(:Concept)
# (:Concept)-[:CONTROLS]->(:Concept)
# (:Concept)-[:RELATES_TO]->(:Concept)
# (:Concept)-[:INFLUENCES]->(:Concept)
# (:Concept)-[:AFFECTS]->(:Concept)
# (:Concept)-[:AFFECTS]->(:Technology)
# (:Concept)-[:SAME_AS]->(:Concept)
# (:Concept)-[:SELECTS_FROM]->(:Concept)
# (:Concept)-[:PART_OF]->(:Concept)
# (:Concept)-[:CLASSIFIES]->(:Content)
# (:Concept)-[:PRECEDES]->(:Concept)
# (:Concept)-[:CONSIDERS]->(:Concept)
# (:Concept)-[:CONTAINS]->(:Example)
# (:Concept)-[:CONTAINS]->(:Concept)
# (:Concept)-[:CONTAINS]->(:List)
# (:Concept)-[:DEFINES]->(:Technology)
# (:Concept)-[:DEFINES]->(:Concept)
# (:Concept)-[:SETS]->(:Concept)
# (:Concept)-[:USED_FOR]->(:Task)
# (:Concept)-[:CAN_OUTPUT]->(:Format)
# (:Concept)-[:CAN_GENERATE]->(:Technology)
# (:Concept)-[:PROVIDES]->(:Concept)
# (:Concept)-[:HELPS_WITH]->(:Concept)
# (:Concept)-[:ACTIVATES]->(:Concept)
# (:Concept)-[:PROMOTES]->(:Concept)
# (:Concept)-[:IMPROVES]->(:Technology)
# (:Concept)-[:IMPROVES]->(:Concept)
# (:Concept)-[:BASED_ON]->(:Concept)
# (:Concept)-[:GENERATES]->(:Concept)
# (:Concept)-[:INCREASES]->(:Concept)
# (:Concept)-[:RELATED_TO]->(:Concept)
# (:Concept)-[:COMBINES_WITH]->(:Concept)
# (:Concept)-[:APPLIES_TO]->(:Concept)
# (:Concept)-[:SOLVED_BY]->(:Concept)
# (:Concept)-[:ENHANCES]->(:Technology)
# (:Concept)-[:GENERALIZES]->(:Concept)
# (:Concept)-[:SUITABLE_FOR]->(:Concept)
# (:Concept)-[:ASSISTS]->(:Technology)
# (:Concept)-[:PROTECTS]->(:Activity)
# (:Concept)-[:SUPPORTS]->(:Activity)
# (:Concept)-[:ILLUSTRATED_BY]->(:Example)
# (:Concept)-[:LIMITS]->(:Concept)
# (:Concept)-[:ENSURES]->(:Concept)
# (:Concept)-[:ENCOURAGES]->(:Concept)
# (:Concept)-[:EXAMPLE_USAGE]->(:Concept)
# (:Concept)-[:EXAMPLE_USAGE]->(:Location)
# (:Technology)-[:PERFORMS]->(:Concept)
# (:Technology)-[:PERFORMS]->(:Task)
# (:Technology)-[:PERFORMS]->(:Activity)
# (:Technology)-[:PROCESSES]->(:Concept)
# (:Technology)-[:PROCESSES]->(:System)
# (:Technology)-[:USES]->(:Concept)
# (:Technology)-[:USES]->(:Technology)
# (:Technology)-[:SUPPORTS]->(:Technology)
# (:Technology)-[:SUPPORTS]->(:Concept)
# (:Technology)-[:REQUIRES]->(:Concept)
# (:Technology)-[:USED_IN]->(:Concept)
# (:Technology)-[:PROVIDES]->(:Concept)
# (:Technology)-[:AFFECTS]->(:Software)
# (:Technology)-[:INTEGRATES_WITH]->(:Technology)
# (:Technology)-[:ANALYZES]->(:Organization)
# (:Technology)-[:SERVES]->(:Business)
# (:Technology)-[:GENERATES]->(:Concept)
# (:Technology)-[:GENERATES]->(:Software)
# (:Technology)-[:TRANSLATES_TO]->(:Technology)
# (:Technology)-[:HANDLES]->(:Concept)
# (:Technology)-[:PART_OF]->(:Technology)
# (:Technology)-[:AVAILABLE_ON]->(:Platform)
# (:Technology)-[:REPAIRS]->(:Technology)
# (:Technology)-[:DEFINES]->(:Technology)
# (:Task)-[:USES]->(:Model)
# (:Task)-[:OUTPUTS]->(:Technology)
# (:Parameter)-[:REQUIRES_VALUE]->(:Output)
# (:Parameter)-[:REQUIRES_VALUE]->(:Task)
# (:Parameter)-[:CAN_CAUSE]->(:Issue)
# (:Parameter)-[:PARAMETER_OF]->(:Concept)
# (:Software)-[:USES]->(:Software)
# (:Software)-[:USES]->(:Variable)
# (:Software)-[:USES]->(:Format)
# (:Software)-[:PART_OF]->(:Software)
# (:Software)-[:PART_OF]->(:Website)
# (:Software)-[:CONTAINS]->(:Feature)
# (:Software)-[:CONTAINS]->(:Software)
# (:Software)-[:CONTAINS_VULNERABILITY]->(:Software)
# (:Software)-[:PROCESSES_ORDERS]->(:Product)
# (:Software)-[:EVALUATES]->(:Software)
# (:Software)-[:PERFORMS]->(:Task)
# (:Software)-[:PERFORMS]->(:Action)
# (:Software)-[:EXECUTES]->(:File)
# (:Software)-[:EXPLAINS]->(:Text)
# (:Movie)-[:HAS_ATTRIBUTE]->(:Attribute)
# (:Movie)-[:ABOUT]->(:Technology)
# (:Movie)-[:EXAMPLE_OF]->(:Task)
# (:Model)-[:PROCESSES]->(:Schema)
# (:Example)-[:INCLUDES]->(:Example)
# (:Example)-[:REFERENCES]->(:Location)
# (:Example)-[:ABOUT]->(:Content)
# (:Process)-[:USES]->(:Tool)
# (:Process)-[:USES]->(:System)
# (:Schema)-[:USES]->(:Format)
# (:Schema)-[:STRUCTURES]->(:System)
# (:Schema)-[:CONTAINS]->(:Property)
# (:Role)-[:DESCRIBES]->(:Location)
# (:Location)-[:LOCATED_IN]->(:Location)
# (:Location)-[:PART_OF]->(:Location)
# (:Location)-[:CONTAINS]->(:Character)
# (:Location)-[:CONTAINS]->(:Location)
# (:Artwork)-[:DISPLAYED_AT]->(:Location)
# (:Artwork)-[:CREATED_BY]->(:Person)
# (:Article)-[:COVERS]->(:Topic)
# (:Blog)-[:CONTAINS]->(:Article)
# (:Group)-[:REPORTS_TO]->(:Location)
# (:Group)-[:LOCATED_IN]->(:Location)
# (:Group)-[:PLANS]->(:Information)
# (:Information)-[:REVEALS]->(:Information)
# (:Character)-[:LOCATED_IN]->(:Location)
# (:System)-[:IMPLEMENTS]->(:Concept)
# (:System)-[:USES]->(:Process)
# (:Bug)-[:AFFECTS]->(:Software)
# (:Code)-[:CREATES]->(:Technology)
# (:Code)-[:USES]->(:Technology)
# (:Code)-[:USES]->(:Service)
# (:Code)-[:TRANSLATES_TO]->(:Code)
# (:Organization)-[:DEVELOPS]->(:Software)
# (:Organization)-[:OWNS]->(:Software)
# (:Business)-[:SELLS]->(:Product)
# (:Product)-[:EXAMPLE_OF]->(:Concept)
# (:Product)-[:BELONGS_TO]->(:Category)
# (:Product)-[:HAS_FEATURE]->(:Feature)
# (:Variable)-[:USED_BY]->(:Function)
# (:Variable)-[:CALLS]->(:Function)
# (:Variable)-[:USED_IN]->(:Variable)
# (:File)-[:RENAMED_TO]->(:File)
# (:File)-[:WRITTEN_IN]->(:Language)
# (:File)-[:CONTAINS]->(:Function)
# (:Folder)-[:CONTAINS]->(:File)
# (:Action)-[:STORES]->(:Variable)
# (:Action)-[:DISPLAYS]->(:Message)
# (:Object)-[:CONTAINS]->(:Object)
# (:Function)-[:GENERATES]->(:Object)
# (:Function)-[:GENERATES]->(:Error)
# (:Function)-[:CREATES]->(:Object)
# (:Function)-[:ITERATES]->(:Object)
# (:Function)-[:ASSIGNS_TO]->(:Variable)
# (:Language)-[:TRANSLATED_TO]->(:Language)
# (:Activity)-[:ANALYZES]->(:Technology)
# (:Tool)-[:PART_OF]->(:Platform)
# (:Tool)-[:SUPPORTS]->(:Concept)
# (:Tool)-[:CONTAINS]->(:Document)
# (:Publication)-[:PUBLISHED_ON]->(:Platform)

# %%
## Visualize the Knowledge-graph 
# Run the function with your Neo4j graph
print("🚀 Creating Neo4j visualization...")
result = visualize_neo4j_graph(graph, max_nodes=500, max_relationships=1000)

if result:
    print(f"\n🎉 Visualization completed!")
    print(f"   📊 Nodes: {result['nodes_count']}")
    print(f"   🔗 Relationships: {result['relationships_count']}")
    print(f"   📁 File: {result['output_file']}")

# %%
# Create the GraphCypherQAChain with the tracker
chain = GraphCypherQAChain.from_llm(
    llm=llm,                             # Use OpenAI LLM for question answering
    graph=graph,                                # Use the Neo4j graph
    #cypher_prompt=custom_cypher_prompt,
    verbose=True,                               # Enable verbose logging
    top_k=15,                                    # Return top 5 results
    allow_dangerous_requests=True,
    #callbacks=[tracker]                         # Add the tracker to the callbacks
)

# %%
question = "details about Tiffany Ramirez"
result = chain.invoke({"query": question})
# Out:
# > Entering new GraphCypherQAChain chain...
# Generated Cypher:
# MATCH (p:Person {id: 'Tiffany Ramirez'})
# OPTIONAL MATCH (p)-[r]->(n)
# OPTIONAL MATCH (n2)-[r2]->(p)
# RETURN p, type(r), n, type(r2), n2
# Full Context:
# [{'p': {'id': 'Tiffany Ramirez'}, 'type(r)': 'ADMITTED_TO', 'n': {'id': 'Wallace-Hamilton'}, 'type(r2)': 'MENTIONS', 'n2': {'id': '8f3321e466358b25925d4a6d89f757e9', 'text': 'Name: Tiffany Ramirez, Age: 81, Gender: Female, Blood Type: O-, Medical Condition: Diabetes, Date of Admission: 2022-11-17, Doctor: Patrick Parker, Hospital: Wallace-Hamilton, Insurance Provider: Medicare, Billing Amount: 37490.98336352819, Room Number: 146, Admission Type: Elective, Discharge Date: 2022-12-01, Medication: Aspirin, Test Results: Inconclusive', 'source': '/Users/kathisnehith/Downloads/healthcare_dataset.csv', 'row': 0}}, {'p': {'id': 'Tiffany Ramirez'}, 'type(r)': 'INSURED_BY', 'n': {'id': 'Medicare'}, 'type(r2)': 'MENTIONS', 'n2': {'id': '8f3321e466358b25925d4a6d89f757e9', 'text': 'Name: Tiffany Ramirez, Age: 81, Gender: Female, Blood Type: O-, Medical Condition: Diabetes, Date of Admission: 2022-11-17, Doctor: Patrick Parker, Hospital: Wallace-Hamilton, Insurance Provider: Medicare, Billing Amount: 37490.98336352819, Room Number: 146, Admission Type: Elective, Discharge Date: 2022-12-01, Medication: Aspirin, Test Results: Inconclusive', 'source': '/Users/kathisnehith/Downloads/healthcare_dataset.csv', 'row': 0}}, {'p': {'id': 'Tiffany Ramirez'}, 'type(r)': 'HAS_CONDITION', 'n': {'id': 'Diabetes'}, 'type(r2)': 'MENTIONS', 'n2': {'id': '8f3321e466358b25925d4a6d89f757e9', 'text': 'Name: Tiffany Ramirez, Age: 81, Gender: Female, Blood Type: O-, Medical Condition: Diabetes, Date of Admission: 2022-11-17, Doctor: Patrick Parker, Hospital: Wallace-Hamilton, Insurance Provider: Medicare, Billing Amount: 37490.98336352819, Room Number: 146, Admission Type: Elective, Discharge Date: 2022-12-01, Medication: Aspirin, Test Results: Inconclusive', 'source': '/Users/kathisnehith/Downloads/healthcare_dataset.csv', 'row': 0}}, {'p': {'id': 'Tiffany Ramirez'}, 'type(r)': 'TAKES', 'n': {'id': 'Aspirin'}, 'type(r2)': 'MENTIONS', 'n2': {'id': '8f3321e466358b25925d4a6d89f757e9', 'text': 'Name: Tiffany Ramirez, Age: 81, Gender: Female, Blood Type: O-, Medical Condition: Diabetes, Date of Admission: 2022-11-17, Doctor: Patrick Parker, Hospital: Wallace-Hamilton, Insurance Provider: Medicare, Billing Amount: 37490.98336352819, Room Number: 146, Admission Type: Elective, Discharge Date: 2022-12-01, Medication: Aspirin, Test Results: Inconclusive', 'source': '/Users/kathisnehith/Downloads/healthcare_dataset.csv', 'row': 0}}, {'p': {'id': 'Tiffany Ramirez'}, 'type(r)': 'ASSIGNED_TO', 'n': {'id': 'Room 146'}, 'type(r2)': 'MENTIONS', 'n2': {'id': '8f3321e466358b25925d4a6d89f757e9', 'text': 'Name: Tiffany Ramirez, Age: 81, Gender: Female, Blood Type: O-, Medical Condition: Diabetes, Date of Admission: 2022-11-17, Doctor: Patrick Parker, Hospital: Wallace-Hamilton, Insurance Provider: Medicare, Billing Amount: 37490.98336352819, Room Number: 146, Admission Type: Elective, Discharge Date: 2022-12-01, Medication: Aspirin, Test Results: Inconclusive', 'source': '/Users/kathisnehith/Downloads/healthcare_dataset.csv', 'row': 0}}, {'p': {'id': 'Tiffany Ramirez'}, 'type(r)': 'ADMITTED_TO', 'n': {'id': 'Wallace-Hamilton'}, 'type(r2)': 'TREATS', 'n2': {'id': 'Patrick Parker'}}, {'p': {'id': 'Tiffany Ramirez'}, 'type(r)': 'INSURED_BY', 'n': {'id': 'Medicare'}, 'type(r2)': 'TREATS', 'n2': {'id': 'Patrick Parker'}}, {'p': {'id': 'Tiffany Ramirez'}, 'type(r)': 'HAS_CONDITION', 'n': {'id': 'Diabetes'}, 'type(r2)': 'TREATS', 'n2': {'id': 'Patrick Parker'}}, {'p': {'id': 'Tiffany Ramirez'}, 'type(r)': 'TAKES', 'n': {'id': 'Aspirin'}, 'type(r2)': 'TREATS', 'n2': {'id': 'Patrick Parker'}}, {'p': {'id': 'Tiffany Ramirez'}, 'type(r)': 'ASSIGNED_TO', 'n': {'id': 'Room 146'}, 'type(r2)': 'TREATS', 'n2': {'id': 'Patrick Parker'}}]
#
# > Finished chain.

# %%
print(f"\n🔍 Question: {question}")
print(f"💡 Answer: {result['result']}")
# Out:
# 🔍 Question: details about Tiffany Ramirez
# 💡 Answer: Tiffany Ramirez is an 81-year-old female patient who was admitted to Wallace-Hamilton Hospital on November 17, 2022, for an elective procedure. She has diabetes and is taking Aspirin as medication. She was assigned to Room 146 during her stay and was discharged on December 1, 2022. Her blood type is O-negative, and she is insured by Medicare. Dr. Patrick Parker was her attending physician, and her test results were inconclusive. The billing amount for her hospital stay was $37,490.98.
